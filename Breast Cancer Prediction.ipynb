# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\LENOVO\Downloads\archive-3\breast-cancer.csv")

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
data.rename(columns={
    'concave points_mean':"concave_points_mean",
    'concave points_worst':"concave_points_worst",
    'concave points_se':'concave_points_se'
},inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave_points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
data.drop('id',axis=1,inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print(data['diagnosis'].value_counts())
plt.figure(figsize=(6, 4))
sns.countplot(x='diagnosis', data=data, palette='viridis')
plt.title('Diagnosis Distribution', fontsize=16)
plt.xlabel('Diagnosis (B: Benign, M: Malignant)', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.show()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_49056\2669419633.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='diagnosis', data=data, palette='viridis')

# %%
data.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave_points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave_points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
data.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
data.iloc[:, 2:].hist(figsize=(16, 12), bins=20, color='skyblue', edgecolor='black')
plt.suptitle("Feature Distributions", fontsize=20)
plt.tight_layout()
plt.show()

# %%
correlation_matrix = data.iloc[:, 2:].corr()

plt.figure(figsize=(18,12))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True, linewidths=0.5)
plt.title('Correlation Matrix with Values', fontsize=16)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import mutual_info_classif

# Ensure pandas displays all rows
pd.set_option('display.max_rows', None)

# Calculate mutual information
X = data.drop(columns=['diagnosis'])
y = data['diagnosis']
mutual_info = mutual_info_classif(X, y)

# Create a DataFrame to rank features
mutual_info_df = pd.DataFrame({'Feature': X.columns, 'Mutual_Info': mutual_info})
mutual_info_df = mutual_info_df.sort_values(by='Mutual_Info', ascending=False)


# Plot the mutual information values
plt.figure(figsize=(12, 8))
sns.barplot(x='Mutual_Info', y='Feature', data=mutual_info_df, palette='viridis')
plt.title('Feature Importance based on Mutual Information', fontsize=16)
plt.xlabel('Mutual Information', fontsize=14)
plt.ylabel('Feature', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_49056\444539491.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Mutual_Info', y='Feature', data=mutual_info_df, palette='viridis')

# %%
data['diagnosis'] = data['diagnosis'].map({'M': 1, 'B': 0})
# Separate the features (X) and the target column (y)
X = data.drop(columns=['diagnosis'])
y = data['diagnosis']

correlation_with_target = data.corr()['diagnosis'].drop('diagnosis').sort_values(ascending=False)

print("Top correlated features with diagnosis:")
plt.figure(figsize=(12, 8))
sns.barplot(x=correlation_with_target.values, y=correlation_with_target.index, palette='coolwarm')
plt.title('Feature Correlation with Diagnosis', fontsize=16)
plt.xlabel('Correlation with Diagnosis', fontsize=14)
plt.ylabel('Feature', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Top correlated features with diagnosis:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_49056\2172048330.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=correlation_with_target.values, y=correlation_with_target.index, palette='coolwarm')

# %%
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
data.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
columns_drop=['fractal_dimension_se','smoothness_se','symmetry_se','fractal_dimension_mean','texture_se','radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean','radius_worst','perimeter_se','area_worst']
data.drop(columns_drop,axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    int64
#  1   radius_se                569 non-null    float64
#  2   area_se                  569 non-null    float64
#  3   compactness_se           569 non-null    float64
#  4   concavity_se             569 non-null    float64
#  5   concave_points_se        569 non-null    float64
#  6   texture_worst            569 non-null    float64
#  7   perimeter_worst          569 non-null    float64
#  8   smoothness_worst         569 non-null    float64
#  9   compactness_worst        569 non-null    float64
#  10  concavity_worst          569 non-null    float64
#  11  concave_points_worst     569 non-null    float64
#  12  symmetry_worst           569 non-null    float64
# ...

# %%
correlation_matrix = data.iloc[:, 2:].corr()

plt.figure(figsize=(18,12))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True, linewidths=0.5)
plt.title('Correlation Matrix with Values', fontsize=16)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
data.columns
# Out:
# Index(['diagnosis', 'radius_se', 'area_se', 'compactness_se', 'concavity_se',
#        'concave_points_se', 'texture_worst', 'perimeter_worst',
#        'smoothness_worst', 'compactness_worst', 'concavity_worst',
#        'concave_points_worst', 'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
data.head()
# Out:
#    diagnosis  radius_se  area_se  compactness_se  concavity_se  \
# 0          1     1.0950   153.40         0.04904       0.05373
# 1          1     0.5435    74.08         0.01308       0.01860
# 2          1     0.7456    94.03         0.04006       0.03832
# 3          1     0.4956    27.23         0.07458       0.05661
# 4          1     0.7572    94.44         0.02461       0.05688
#
#    concave_points_se  texture_worst  perimeter_worst  smoothness_worst  \
# 0            0.01587          17.33           184.60            0.1622
# 1            0.01340          23.41           158.80            0.1238
# 2            0.02058          25.53           152.50            0.1444
# 3            0.01867          26.50            98.87            0.2098
# 4            0.01885          16.67           152.20            0.1374
#
#    compactness_worst  concavity_worst  concave_points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Apply Standard Scaling to the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convert the scaled features back into a DataFrame
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

# %%
from sklearn.model_selection import train_test_split

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

class ModelTrainer:
    def __init__(self, X_train, X_test, y_train, y_test):
        self.X_train = X_train
        self.X_test = X_test
        self.y_train = y_train
        self.y_test = y_test

    def train_random_forest(self):
        rf = RandomForestClassifier(
            n_estimators=200,
            max_features='sqrt',
            max_depth=None,
            min_samples_split=2,
            min_samples_leaf=1,
            bootstrap=True,
            random_state=42
        )
        rf.fit(self.X_train, self.y_train)
        y_pred = rf.predict(self.X_test)
        accuracy = accuracy_score(self.y_test, y_pred)
        report = classification_report(self.y_test, y_pred)
        return accuracy, report

    def train_xgboost(self):
        xgb_model = xgb.XGBClassifier(
            n_estimators=200,
            max_depth=6,
            learning_rate=0.1,
            subsample=0.8,
            colsample_bytree=0.8,
            random_state=42
        )
        xgb_model.fit(self.X_train, self.y_train)
        y_pred_xgb = xgb_model.predict(self.X_test)
        accuracy_xgb = accuracy_score(self.y_test, y_pred_xgb)
        report_xgb = classification_report(self.y_test, y_pred_xgb)
        return accuracy_xgb, report_xgb

    def train_logistic_regression(self):
        log_reg = LogisticRegression(
            max_iter=1000,
            solver='liblinear',
            random_state=42
        )
        log_reg.fit(self.X_train, self.y_train)
        y_pred_log_reg = log_reg.predict(self.X_test)
        accuracy_log_reg = accuracy_score(self.y_test, y_pred_log_reg)
        report_log_reg = classification_report(self.y_test, y_pred_log_reg)
        return accuracy_log_reg, report_log_reg

    def train_svm(self):
        svm_model = SVC(C=1.0, kernel='rbf', random_state=42)
        svm_model.fit(self.X_train, self.y_train)
        y_pred_svm = svm_model.predict(self.X_test)
        accuracy_svm = accuracy_score(self.y_test, y_pred_svm)
        report_svm = classification_report(self.y_test, y_pred_svm)
        return accuracy_svm, report_svm

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

trainer = ModelTrainer(X_train, X_test, y_train, y_test)

# Train and evaluate RandomForest
accuracy_rf, report_rf = trainer.train_random_forest()
print(f"Random Forest Accuracy: {accuracy_rf:.4f}")
print("Random Forest Classification Report:")
print(report_rf)

# Train and evaluate XGBoost
accuracy_xgb, report_xgb = trainer.train_xgboost()
print(f"XGBoost Accuracy: {accuracy_xgb:.4f}")
print("XGBoost Classification Report:")
print(report_xgb)

# Train and evaluate Logistic Regression
accuracy_log_reg, report_log_reg = trainer.train_logistic_regression()
print(f"Logistic Regression Accuracy: {accuracy_log_reg:.4f}")
print("Logistic Regression Classification Report:")
print(report_log_reg)

# Train and evaluate SVM
accuracy_svm, report_svm = trainer.train_svm()
print(f"SVM Accuracy: {accuracy_svm:.4f}")
print("SVM Classification Report:")
print(report_svm)
# Out:
# Random Forest Accuracy: 0.9708
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       108
#            1       0.98      0.94      0.96        63
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.96      0.97       171
# weighted avg       0.97      0.97      0.97       171
#
# XGBoost Accuracy: 0.9708
# XGBoost Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       108
#            1       0.95      0.97      0.96        63
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.97      0.97       171
# weighted avg       0.97      0.97      0.97       171
#
# Logistic Regression Accuracy: 0.9649
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
# ...
